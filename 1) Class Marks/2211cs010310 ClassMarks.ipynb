# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('class_marks.csv')
print(data.isnull().sum())
# Out:
# Total     0
# Q1aM4     1
# Q1bM6    13
# Q2aM6    14
# Q2bM4    11
# Q3aM5    34
# Q3bM5    35
# Q4aM3    54
# Q4bM7    60
# Q5M10    30
# Q6aM4    53
# Q6bM6    58
# dtype: int64

# %%
data.head()
# Out:
#    Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0     37    4.0    5.0    6.0    4.0    2.0    1.0    NaN    5.0    8.0
# 1     32    4.0    3.0    4.0    3.0    NaN    NaN    3.0    6.0    9.0
# 2     33    4.0    5.0    5.0    1.0    5.0    5.0    NaN    NaN    8.0
# 3     24    4.0    6.0    6.0    3.0    2.0    2.0    NaN    NaN    NaN
# 4     36    3.0    6.0    4.0    4.0    5.0    4.0    NaN    NaN   10.0
#
#    Q6aM4  Q6bM6
# 0    4.0    6.0
# 1    NaN    NaN
# 2    NaN    NaN
# 3    2.0    NaN
# 4    NaN    NaN

# %%
data
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37    4.0    5.0    6.0    4.0    2.0    1.0    NaN    5.0    8.0
# 1      32    4.0    3.0    4.0    3.0    NaN    NaN    3.0    6.0    9.0
# 2      33    4.0    5.0    5.0    1.0    5.0    5.0    NaN    NaN    8.0
# 3      24    4.0    6.0    6.0    3.0    2.0    2.0    NaN    NaN    NaN
# 4      36    3.0    6.0    4.0    4.0    5.0    4.0    NaN    NaN   10.0
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32    3.0    6.0    3.0    4.0    5.0    3.0    NaN    NaN    NaN
# 82     27    2.0    2.0    5.0    3.0    NaN    NaN    NaN    NaN    7.0
# 83     37    4.0    6.0    6.0    2.0    NaN    NaN    NaN    NaN    9.0
# 84     28    4.0    NaN    5.0    4.0    5.0    4.0    NaN    NaN    6.0
# 85     29    4.0    6.0    NaN    NaN    NaN    NaN    3.0    5.0    7.0
#
#     Q6aM4  Q6bM6
# 0     4.0    6.0
# 1     NaN    NaN
# 2     NaN    NaN
# 3     2.0    NaN
# ...

# %%
data.loc[15:20]
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 15     32    3.0    NaN    2.0    1.0    5.0    5.0    3.0    7.0    NaN
# 16     30    4.0    NaN    6.0    4.0    5.0    2.0    NaN    NaN    8.0
# 17     36    3.0    4.0    6.0    4.0    NaN    NaN    NaN    NaN    9.0
# 18     24    3.0    3.0    5.0    3.0    NaN    NaN    2.0    1.0    7.0
# 19     26    3.0    NaN    6.0    4.0    NaN    2.0    2.0    1.0    7.0
# 20     29    2.0    6.0    2.0    2.0    5.0    5.0    NaN    NaN    7.0
#
#     Q6aM4  Q6bM6
# 15    4.0    6.0
# 16    NaN    NaN
# 17    4.0    6.0
# 18    NaN    NaN
# 19    3.0    NaN
# 20    NaN    NaN

# %%
data["Q1"]=data["Q1aM4"]+data["Q1bM6"]

# %%
data
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37    4.0    5.0    6.0    4.0    2.0    1.0    NaN    5.0    8.0
# 1      32    4.0    3.0    4.0    3.0    NaN    NaN    3.0    6.0    9.0
# 2      33    4.0    5.0    5.0    1.0    5.0    5.0    NaN    NaN    8.0
# 3      24    4.0    6.0    6.0    3.0    2.0    2.0    NaN    NaN    NaN
# 4      36    3.0    6.0    4.0    4.0    5.0    4.0    NaN    NaN   10.0
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32    3.0    6.0    3.0    4.0    5.0    3.0    NaN    NaN    NaN
# 82     27    2.0    2.0    5.0    3.0    NaN    NaN    NaN    NaN    7.0
# 83     37    4.0    6.0    6.0    2.0    NaN    NaN    NaN    NaN    9.0
# 84     28    4.0    NaN    5.0    4.0    5.0    4.0    NaN    NaN    6.0
# 85     29    4.0    6.0    NaN    NaN    NaN    NaN    3.0    5.0    7.0
#
#     Q6aM4  Q6bM6    Q1
# 0     4.0    6.0   9.0
# 1     NaN    NaN   7.0
# ...

# %%
data["Q2"]=data["Q2aM6"]+data["Q2bM4"]
data["Q3"]=data["Q3aM5"]+data["Q3bM5"]
data["Q4"]=data["Q4aM3"]+data["Q4bM7"]
data["Q6"]=data["Q6aM4"]+data["Q6bM6"]

# %%
data
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37    4.0    5.0    6.0    4.0    2.0    1.0    NaN    5.0    8.0
# 1      32    4.0    3.0    4.0    3.0    NaN    NaN    3.0    6.0    9.0
# 2      33    4.0    5.0    5.0    1.0    5.0    5.0    NaN    NaN    8.0
# 3      24    4.0    6.0    6.0    3.0    2.0    2.0    NaN    NaN    NaN
# 4      36    3.0    6.0    4.0    4.0    5.0    4.0    NaN    NaN   10.0
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32    3.0    6.0    3.0    4.0    5.0    3.0    NaN    NaN    NaN
# 82     27    2.0    2.0    5.0    3.0    NaN    NaN    NaN    NaN    7.0
# 83     37    4.0    6.0    6.0    2.0    NaN    NaN    NaN    NaN    9.0
# 84     28    4.0    NaN    5.0    4.0    5.0    4.0    NaN    NaN    6.0
# 85     29    4.0    6.0    NaN    NaN    NaN    NaN    3.0    5.0    7.0
#
#     Q6aM4  Q6bM6    Q1    Q2    Q3   Q4    Q6
# ...

# %%
data.drop("Q1aM4",axis=1,inplace=True)
data.drop("Q1bM6",axis=1,inplace=True)
data.drop("Q2aM6",axis=1,inplace=True)
data.drop("Q2bM4",axis=1,inplace=True)
data.drop("Q3aM5",axis=1,inplace=True)
data.drop("Q3bM5",axis=1,inplace=True)
data.drop("Q4aM3",axis=1,inplace=True)
data.drop("Q4bM7",axis=1,inplace=True)
data.drop("Q6aM4",axis=1,inplace=True)
data.drop("Q6bM6",axis=1,inplace=True)

# %%
data.loc[(data["Q6"]==10) & (data["Total"]==40)]
# Out:
#     Total  Q5M10    Q1    Q2    Q3    Q4    Q6
# 33     40    NaN   0.0  10.0  10.0  10.0  10.0
# 73     40   10.0  10.0   NaN  10.0   NaN  10.0

# %%
data.rename(columns = {'Q5M10':'Q5'}, inplace = True)
data
# Out:
#     Total    Q5    Q1    Q2    Q3   Q4    Q6
# 0      37   8.0   9.0  10.0   3.0  NaN  10.0
# 1      32   9.0   7.0   7.0   NaN  9.0   NaN
# 2      33   8.0   9.0   6.0  10.0  NaN   NaN
# 3      24   NaN  10.0   9.0   4.0  NaN   NaN
# 4      36  10.0   9.0   8.0   9.0  NaN   NaN
# ..    ...   ...   ...   ...   ...  ...   ...
# 81     32   NaN   9.0   7.0   8.0  NaN  10.0
# 82     27   7.0   4.0   8.0   NaN  NaN   8.0
# 83     37   9.0  10.0   8.0   NaN  NaN  10.0
# 84     28   6.0   0.0   9.0   9.0  NaN   NaN
# 85     29   7.0  10.0   NaN   NaN  8.0   5.0
#
# [86 rows x 7 columns]

# %%
data.plot()
# Out:
# <Axes: >

# %%
a=data.loc[(data['Total'] >= 15) & (data['Total'] <= 20)]
a=a.reset_index()
a
# Out:
#    index  Total   Q5    Q1    Q2   Q3    Q4  Q6
# 0      5     20  NaN  10.0  10.0  NaN   NaN NaN
# 1     30     20  NaN   8.0   8.0  NaN   NaN NaN
# 2     34     19  5.0   5.0   4.0  5.0   NaN NaN
# 3     57     17  NaN   0.0   NaN  NaN  10.0 NaN
# 4     60     20  8.0   7.0   5.0  NaN   NaN NaN
# 5     63     18  8.0   0.0   6.0  NaN   NaN NaN
# 6     68     20  NaN  10.0  10.0  NaN   NaN NaN
# 7     76     17  NaN   5.0   6.0  6.0   NaN NaN

# %% [markdown]
# # Total marks 15-20 is filtered above

# %%
a1=a.groupby('Q1')['Total']
a1.hist(color='yellow',figsize=[8,8],grid=False,bins=5)
plt.title("Histogram of students who scored 15-20 Total Marks")
plt.xlabel("Total Marks obtained")
plt.ylabel("Marks in Q1")
plt.show()

# %% [markdown]
# # Most of the students scored 1M in Q1 and students who got 20M got 2M in Q1

# %%
a2=a.groupby('Q2')['Total']
a2.hist(color='yellow',figsize=[8,8],grid=False,bins=5)
plt.title("Histogram of students who scored 15-20 Total Marks")
plt.xlabel("Total Marks obtained")
plt.ylabel("Marks in Q2")
plt.show()

# %% [markdown]
# # Most of the students scored 1M in Q2 students who got 20M got 2M in Q2

# %%
a3=a.groupby('Q3')['Total']
a3.hist(color='RED',figsize=[8,8],grid=False,bins=7)
plt.title("Histogram of students who scored 15-20 Total Marks")
plt.xlabel("Total Marks obtained")
plt.ylabel("Marks in Q3")
plt.show()

# %% [markdown]
# # Students who got 17M and 19M got 1M in Q3

# %%
a4=a.groupby('Q4')['Total']
a2.hist(color='green',figsize=[8,8],grid=False,bins=4)
plt.title("Histogram of students who scored 15-20 Total Marks")
plt.xlabel("Total Marks obtained")
plt.ylabel("Marks in Q4")
plt.show()

# %% [markdown]
# # Students who got 17,18, and 19 marks got 1M and who got 20M got 2M in Q4

# %%
a5=a.groupby('Q5')['Total']
a5.hist(color='purple',figsize=[8,8],grid=False,bins=6)
plt.title("Histogram of students who scored 15-20 Total Marks")
plt.xlabel("Total Marks obtained")
plt.ylabel("Marks in Q5")
plt.show()

# %% [markdown]
# # So many students attempted Q5 and got 1M in Q5

# %%
a6=a.groupby('Q6')['Total']
a6.hist(color='orange',figsize=[8,8],grid=False,bins=8)
plt.title("Histogram of students who scored 15-20 Total Marks")
plt.xlabel("Total Marks obtained")
plt.ylabel("Marks in Q6")
plt.show()

# %% [markdown]
# # Students who got 15-20M didnt attempt Q6

# %%
b=data.loc[(data['Total'] >= 20) & (data['Total'] <= 25)]
b=b.reset_index()
b
# Out:
#     index  Total   Q5    Q1    Q2    Q3    Q4    Q6
# 0       3     24  NaN  10.0   9.0   4.0   NaN   NaN
# 1       5     20  NaN  10.0  10.0   NaN   NaN   NaN
# 2       6     25  6.0   7.0   NaN  10.0   NaN   NaN
# 3      18     24  7.0   6.0   8.0   NaN   3.0   NaN
# 4      25     22  NaN   6.0   7.0   7.0   NaN   NaN
# 5      30     20  NaN   8.0   8.0   NaN   NaN   NaN
# 6      39     22  NaN   5.0   NaN   6.0   NaN   8.0
# 7      48     25  8.0   8.0   NaN   NaN   9.0   NaN
# 8      50     24  5.0   9.0   NaN  10.0   NaN  10.0
# 9      54     21  NaN   8.0   NaN  10.0   NaN  10.0
# 10     60     20  8.0   7.0   5.0   NaN   NaN   NaN
# 11     61     24  NaN   9.0  10.0   NaN   NaN  10.0
# 12     68     20  NaN  10.0  10.0   NaN   NaN   NaN
# 13     72     25  NaN   0.0   8.0   NaN  10.0   NaN
# 14     74     25  9.0   6.0  10.0   NaN   NaN   NaN
# 15     75     21  8.0   0.0   7.0   2.0   NaN   NaN
# 16     77     22  NaN   9.0   NaN   5.0   NaN   6.0

# %% [markdown]
# # Total marks 20-25 is filtered from the data set

# %%
b.plot.scatter(x='Q1',y='Total',color='green',s=40)
plt.title("20-25 Marks ANALYSIS")
plt.show()

# %% [markdown]
# # students who got 20-25 marks in total scored highest 6M in Q1

# %%
b.plot.scatter(x='Q2',y='Total',color='red',s=40)
plt.title("20-25 Marks ANALYSIS")
plt.show()

# %% [markdown]
# # 3 students got 10 marks and 8 M in Q2

# %%
b.plot.scatter(x='Q3',y='Total',color='black',s=40)
plt.title("20-25 Marks ANALYSIS")
plt.show()

# %% [markdown]
# # 3students got 10 marks in Q2

# %%
b.plot.scatter(x='Q4',y='Total',color='blue',s=40)
plt.title("20-25 Marks ANALYSIS")
plt.show()

# %% [markdown]
# # students who got 20-25 marks less number of students attempted Q3

# %%
b.plot.scatter(x='Q5',y='Total',color='purple',s=40)
plt.title("20-25 Marks ANALYSIS")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # Students who got 25M in total got 6,8 and 9M in Q5

# %%
c=data.loc[(data['Total'] >= 25) & (data['Total'] <= 30)]
c=c.reset_index()
c
# Out:
#     index  Total    Q5    Q1    Q2    Q3    Q4   Q6
# 0       6     25   6.0   7.0   NaN  10.0   NaN  NaN
# 1       8     27   9.0   8.0   NaN   NaN   NaN  NaN
# 2      14     30   NaN  10.0   8.0   9.0   NaN  NaN
# 3      16     30   8.0   0.0  10.0   7.0   NaN  NaN
# 4      19     26   7.0   0.0  10.0   NaN   3.0  NaN
# 5      20     29   7.0   8.0   4.0  10.0   NaN  NaN
# 6      29     27   NaN   0.0   7.0   NaN   NaN  9.0
# 7      31     26   NaN   7.0   8.0   NaN   NaN  8.0
# 8      35     30   8.0  10.0  10.0   NaN   NaN  NaN
# 9      38     28   NaN   9.0  10.0   8.0   NaN  NaN
# 10     40     29   7.0  10.0  10.0   NaN   2.0  NaN
# 11     41     26   4.0   5.0   7.0   7.0   NaN  NaN
# 12     48     25   8.0   8.0   NaN   NaN   9.0  NaN
# 13     52     29   4.0   9.0   7.0   NaN   9.0  NaN
# 14     67     28  10.0  10.0   8.0   NaN   NaN  NaN
# 15     72     25   NaN   0.0   8.0   NaN  10.0  NaN
# 16     74     25   9.0   6.0  10.0   NaN   NaN  NaN
# ...

# %% [markdown]
# # Students who got 25 to 30 Marks in total

# %%
c.boxplot(by='Q1', column =['Total'], grid = False,color='Green',figsize=[5,6])
plt.title("25-30 Marks")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # Maximum number of students scored 8M in Q1

# %%
c.boxplot(by='Q4', column =['Total'], grid = False,color='red',figsize=[5,6])
plt.title("25-30 Marks")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # Maximum number of students scored 9M in Q2

# %%
c.boxplot(by='Q5', column =['Total'], grid = False,color='purple',figsize=[5,6])
plt.title("25-30 Marks")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # Maximum number of students attempted Q5 and for marks between 4-10 M

# %%
d=data.loc[(data['Total']>=25) & (data['Total']<=30)]
d=d.reset_index()
d
# Out:
#     index  Total    Q5    Q1    Q2    Q3    Q4   Q6
# 0       6     25   6.0   7.0   NaN  10.0   NaN  NaN
# 1       8     27   9.0   8.0   NaN   NaN   NaN  NaN
# 2      14     30   NaN  10.0   8.0   9.0   NaN  NaN
# 3      16     30   8.0   0.0  10.0   7.0   NaN  NaN
# 4      19     26   7.0   0.0  10.0   NaN   3.0  NaN
# 5      20     29   7.0   8.0   4.0  10.0   NaN  NaN
# 6      29     27   NaN   0.0   7.0   NaN   NaN  9.0
# 7      31     26   NaN   7.0   8.0   NaN   NaN  8.0
# 8      35     30   8.0  10.0  10.0   NaN   NaN  NaN
# 9      38     28   NaN   9.0  10.0   8.0   NaN  NaN
# 10     40     29   7.0  10.0  10.0   NaN   2.0  NaN
# 11     41     26   4.0   5.0   7.0   7.0   NaN  NaN
# 12     48     25   8.0   8.0   NaN   NaN   9.0  NaN
# 13     52     29   4.0   9.0   7.0   NaN   9.0  NaN
# 14     67     28  10.0  10.0   8.0   NaN   NaN  NaN
# 15     72     25   NaN   0.0   8.0   NaN  10.0  NaN
# 16     74     25   9.0   6.0  10.0   NaN   NaN  NaN
# ...

# %% [markdown]
# # Total marks25-30 is filtered from the data set

# %%
d.plot.line(x='Q1',y='Total',color='red')
plt.title("Line Graph of Q1")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # Maximum number of students scored in range of 4 to 8 and some of the students scored 10M

# %%
d.plot.line(x='Q2',y='Total',color='red')
plt.title("Line Graph of Q2")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # So many students scored 10 M in Q2

# %%
d.plot.line(x='Q3',y='Total',color='green')
plt.title("Line Graph of Q3")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # Students scored 7, 8 and 9M and total is 30M

# %%
d.plot.line(x='Q4',y='Total',color='blue')
plt.title("Line Graph of Q4")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # Students who scored 25 - 30 M got 9M in Q4

# %%
d.plot.line(x='Q5',y='Total',color='violet')
plt.title("Line Graph of Q5")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # Students Scored 29m in Total got 4 to 10 M in Q5

# %%
a=data.loc[(data['Total'] >= 15) & (data['Total'] <= 20)]
a=a.reset_index()
a
# Out:
#    index  Total   Q5    Q1    Q2   Q3    Q4  Q6
# 0      5     20  NaN  10.0  10.0  NaN   NaN NaN
# 1     30     20  NaN   8.0   8.0  NaN   NaN NaN
# 2     34     19  5.0   5.0   4.0  5.0   NaN NaN
# 3     57     17  NaN   0.0   NaN  NaN  10.0 NaN
# 4     60     20  8.0   7.0   5.0  NaN   NaN NaN
# 5     63     18  8.0   0.0   6.0  NaN   NaN NaN
# 6     68     20  NaN  10.0  10.0  NaN   NaN NaN
# 7     76     17  NaN   5.0   6.0  6.0   NaN NaN

# %%
a['Q1'].plot(kind='pie',subplots=True,figsize=(8,8))
plt.title("Pie Chart of Q1")
# Out:
# Text(0.5, 1.0, 'Pie Chart of Q1')

# %% [markdown]
# # From the above pie chart we can deduce that most of
# # the students who attempted the question scored marks
# # between 4 and 7, the minimum mark is 0

# %%
a['Q2'].plot(kind='pie',subplots=True,figsize=(8,8))
plt.title("Pie Chart of Q1")
# Out:
# Text(0.5, 1.0, 'Pie Chart of Q1')

# %% [markdown]
# #  More Number of students scored 4 - 7 M in the Q2

# %%
a['Q3'].plot(kind='pie',subplots=True,figsize=(8,8))
plt.title("Pie Chart of Q3")
# Out:
# Text(0.5, 1.0, 'Pie Chart of Q3')

# %% [markdown]
# # Most  number of students scored 7M in Q3

# %%
a['Q5'].plot(kind='pie',subplots=True,figsize=(8,8))
plt.title("Pie Chart of 5")
# Out:
# Text(0.5, 1.0, 'Pie Chart of 5')

# %% [markdown]
# # So many students got 4, 5 M in Q5
